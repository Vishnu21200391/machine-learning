# %%
import pandas as pd

# %%
data = {
    "Name" : ['Ajay','Amit','Keerthi','Prem','Priya','Pragna'],
    "Stream" : ['Math','Commerce', 'Science', 'Math','Math','Science'],
    "Percentage" : [88,92,95,70,65,78]
}

df = pd.DataFrame(data)
df
# Out:
#       Name    Stream  Percentage
# 0     Ajay      Math          88
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95
# 3     Prem      Math          70
# 4    Priya      Math          65
# 5   Pragna   Science          78

# %%
df[df['Percentage'] > 80]
# Out:
#       Name    Stream  Percentage
# 0     Ajay      Math          88
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95

# %%
df.loc[df['Percentage'] > 80]
# Out:
#       Name    Stream  Percentage
# 0     Ajay      Math          88
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95

# %%
df.loc[:,['Name','Percentage']]
# Out:
#       Name  Percentage
# 0     Ajay          88
# 1     Amit          92
# 2  Keerthi          95
# 3     Prem          70
# 4    Priya          65
# 5   Pragna          78

# %%
df.loc[df['Percentage'] > 80,['Name','Percentage']]
# Out:
#       Name  Percentage
# 0     Ajay          88
# 1     Amit          92
# 2  Keerthi          95

# %%
df.loc[df['Name'] == "Ajay", 'Percentage'] = 90

# %%
df
# Out:
#       Name    Stream  Percentage
# 0     Ajay      Math          90
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95
# 3     Prem      Math          70
# 4    Priya      Math          65
# 5   Pragna   Science          78

# %%
df.loc[(df['Stream'] == "Science") & (df['Percentage'] > 90)]
# Out:
#       Name   Stream  Percentage
# 2  Keerthi  Science          95

# %%
df[df['Stream'] != 'Math']
# Out:
#       Name    Stream  Percentage
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95
# 5   Pragna   Science          78

# %%
df.iloc[:2,:2]
# Out:
#    Name    Stream
# 0  Ajay      Math
# 1  Amit  Commerce

# %%
df.sort_values(by='Stream')
# Out:
#       Name    Stream  Percentage
# 1     Amit  Commerce          92
# 0     Ajay      Math          90
# 3     Prem      Math          70
# 4    Priya      Math          65
# 2  Keerthi   Science          95
# 5   Pragna   Science          78

# %%
x = df[df['Stream'] != 'Math']
x
# Out:
#       Name    Stream  Percentage
# 1     Amit  Commerce          92
# 2  Keerthi   Science          95
# 5   Pragna   Science          78
